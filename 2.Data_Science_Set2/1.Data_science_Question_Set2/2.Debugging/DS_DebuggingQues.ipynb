# %% [markdown]
# ## 1. Central Tendency - Mean, Median, Mode

# %%
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = np.mode(data)
median_val = np.mean(data)
mode_val = stats.median(data)

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)

# %%
AttributeError : module 'numpy' has no attribute 'mode'
stats has no attribute 'median'

statistics --> for mode
numpy --> for mean, median

# %%
import numpy as np
from scipy import stats

data = [10, 15, 15, 20, 25]

mean_val = stats.mode(data)
median_val = np.mean(data)
mode_val = np.median(data)

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)

# %% [markdown]
# ## 2. Percentile Calculation

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 120)
print("90th Percentile:", percentile_90)

# %%
[percentile must be between 0 and 100]
we have 4 quartiles only
Q1 = 25th percentile
Q2 = 50th percentile (median)
Q3 = 75th percentile
Q4 = 100th percentile (max value)

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

percentile_90 = np.percentile(data, 90)
print("90th Percentile:", percentile_90)
# Out:
# 90th Percentile: 46.0

# %% [markdown]
# ## 3. Outlier Detection using IQR

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, 0.25, 0.75)
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)

# %%
TypeError: percentile should not be in decimals form

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, 25, 75)
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)

# %%
AxisError: axis 75 is out of bounds for array of dimension 1

# %%
import numpy as np

data = [10, 12, 14, 16, 18, 100]

Q1, Q3 = np.percentile(data, [25, 75])
IQR = Q3 - Q1
outliers = [x for x in data if x < (Q1 - 1.5 * IQR) or x > (Q3 + 1.5 * IQR)]

print("Outliers:", outliers)
# Out:
# Outliers: [100]

# %% [markdown]
# ## 4. Standard Deviation Calculation

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data, unbiased=True)

print("Standard Deviation:", std_dev)

# %%
TypeError: 'unbiased' is an invalid keyword argument for np.std

# %%
import numpy as np

data = [10, 20, 30, 40, 50]

std_dev = np.std(data)

print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 14.142135623730951

# %% [markdown]
# ## 5. Hypothesis Testing using T-Test

# %%
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=1)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# %%
AxisError : axis 1 is out of bounds for array of dimension 1
t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=0)

# %%
from scipy import stats

medication_group = [110, 115, 108, 102, 107]
placebo_group = [120, 125, 130, 122, 128]

t_stat, p_value = stats.ttest_ind(medication_group, placebo_group, axis=0)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# T-Statistic: -5.921023912553299
# P-Value: 0.0003532844625064416

# %% [markdown]
# ## 6.Multicollinearity Detection Using VIF

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1], -1)]

print(vif_data)

# %%
ValueError: Length of values (0) does not match length of index (3)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.DataFrame({
    'Age': [5, 3, 8, 2, 1, 7, 4, 6, 3, 9],
    'Mileage': [50000, 30000, 80000, 20000, 15000, 70000, 40000, 60000, 35000, 90000],
    'EngineSize': [1.2, 1.6, 2.0, 1.0, 1.3, 2.5, 1.8, 2.2, 1.5, 2.8]
})

vif_data = pd.DataFrame()
vif_data['Feature'] = data.columns
vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]  #10,3

print(vif_data)
# Out:
#       Feature          VIF
# 0         Age   885.531249
# 1     Mileage  1059.299089
# 2  EngineSize    22.929372

# %%
data.shape
# Out:
# (10, 3)

# %%
data.values
# Out:
# array([[5.0e+00, 5.0e+04, 1.2e+00],
#        [3.0e+00, 3.0e+04, 1.6e+00],
#        [8.0e+00, 8.0e+04, 2.0e+00],
#        [2.0e+00, 2.0e+04, 1.0e+00],
#        [1.0e+00, 1.5e+04, 1.3e+00],
#        [7.0e+00, 7.0e+04, 2.5e+00],
#        [4.0e+00, 4.0e+04, 1.8e+00],
#        [6.0e+00, 6.0e+04, 2.2e+00],
#        [3.0e+00, 3.5e+04, 1.5e+00],
#        [9.0e+00, 9.0e+04, 2.8e+00]])
